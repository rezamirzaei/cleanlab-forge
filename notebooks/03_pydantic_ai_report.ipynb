# %% [markdown]
# # 03 — PydanticAI report (optional)
#
# This notebook reads `artifacts/last_result.json` and generates a structured report.
#
# - If `pydantic-ai` is installed and an API key is configured, it will use an LLM.
# - Otherwise it falls back to a deterministic report.

# %%
from pathlib import Path
import sys

cwd = Path.cwd()
if (cwd / "src").exists():
    sys.path.insert(0, str(cwd / "src"))
elif (cwd.parent / "src").exists():
    sys.path.insert(0, str(cwd.parent / "src"))

# %%
from cleanlab_demo.ai.report import generate_ai_report

print(generate_ai_report())
# Out:
# 2026-02-07 21:31:36 | INFO     | cleanlab_demo | Generating AI report using openai:gpt-4o-mini
# 2026-02-07 21:31:37 | WARNING  | cleanlab_demo | AI report generation failed: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable, using deterministic fallback
# {
#   "headline": "adult_income / logistic_regression (classification)",
#   "summary": "Found 50 potential label issues (if Cleanlab enabled). Primary metric: 0.9014128559102674",
#   "key_metrics": {
#     "accuracy": 0.856875,
#     "f1_weighted": 0.8489472102075996,
#     "roc_auc": 0.9014128559102674
#   },
#   "recommended_next_steps": [
#     "Inspect top-ranked label issues and verify labels manually.",
#     "Try training after removing/relabelling the worst issues and compare metrics.",
#     "Compare at least 2 different models (linear + tree/boosting) to validate robustness."
#   ]
# }
